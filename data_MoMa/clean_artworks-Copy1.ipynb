# %%
#import libraries

import pandas as pd
import numpy as np
import re

from getpass import getpass
import sqlalchemy as alch 
from sqlalchemy import create_engine
import datetime
import pymysql
pymysql.install_as_MySQLdb()

# %%
artworks = pd.read_csv('../data_MoMa/artworks.csv')
artworks.head()
# Out:
#    Artwork ID                                              Title Artist ID
# 0           2  Ferdinandsbrücke Project, Vienna, Austria, Ele...      6210  \
# 1           3  City of Music, National Superior Conservatory ...      7470
# 2           4  Villa near Vienna Project, Outside Vienna, Aus...      7605
# 3           5  The Manhattan Transcripts Project, New York, N...      7056
# 4           6  Villa, project, outside Vienna, Austria, Exter...      7605
#
#                        Name  Date
# 0               Otto Wagner  1896  \
# 1  Christian de Portzamparc  1987
# 2                Emil Hoppe  1903
# 3           Bernard Tschumi  1980
# 4                Emil Hoppe  1903
#
#                                               Medium
# 0      Ink and cut-and-pasted painted pages on paper  \
# 1                  Paint and colored pencil on print
# 2  Graphite, pen, color pencil, ink, and gouache ...
# 3  Photographic reproduction with colored synthet...
# 4  Graphite, color pencil, ink, and gouache on tr...
#
#                            Dimensions Acquisition Date
# 0  19 1/8 x 66 1/2" (48.6 x 168.9 cm)       1996-04-09  \
# 1       16 x 11 3/4" (40.6 x 29.8 cm)       1995-01-17
# 2   13 1/2 x 12 1/2" (34.3 x 31.8 cm)       1997-01-15
# 3           20 x 20" (50.8 x 50.8 cm)       1995-01-17
# 4    15 1/8 x 7 1/2" (38.4 x 19.1 cm)       1997-01-15
#
#                                               Credit Catalogue  ...
# 0  Fractional and promised gift of Jo Carole and ...         Y  ...  \
# 1  Gift of the architect in honor of Lily Auchinc...         Y  ...
# 2             Gift of Jo Carole and Ronald S. Lauder         Y  ...
# 3  Purchase and partial gift of the architect in ...         Y  ...
# 4             Gift of Jo Carole and Ronald S. Lauder         Y  ...
#
#   Classification Object Number Diameter (cm)  Circumference (cm)  Height (cm)
# 0   Architecture      885.1996           NaN                 NaN      48.6000  \
# 1   Architecture        1.1995           NaN                 NaN      40.6401
# 2   Architecture        1.1997           NaN                 NaN      34.3000
# 3   Architecture        2.1995           NaN                 NaN      50.8000
# 4   Architecture        2.1997           NaN                 NaN      38.4000
#
#    Length (cm)  Width (cm)  Depth (cm)  Weight (kg)  Duration (s)
# 0          NaN    168.9000         NaN          NaN           NaN
# 1          NaN     29.8451         NaN          NaN           NaN
# 2          NaN     31.8000         NaN          NaN           NaN
# 3          NaN     50.8000         NaN          NaN           NaN
# 4          NaN     19.1000         NaN          NaN           NaN
#
# [5 rows x 21 columns]

# %%
#check for duplicate rows
artworks.duplicated().sum()
# Out:
# 0

# %%
#drop unnecessary columns
artworks.drop(columns = ['Catalogue', 'Diameter (cm)', 'Circumference (cm)', 'Height (cm)',
                         'Length (cm)', 'Width (cm)', 'Depth (cm)', 'Weight (kg)', 'Duration (s)'], inplace=True)

# %%
artworks.head()
# Out:
#    Artwork ID                                              Title Artist ID
# 0           2  Ferdinandsbrücke Project, Vienna, Austria, Ele...      6210  \
# 1           3  City of Music, National Superior Conservatory ...      7470
# 2           4  Villa near Vienna Project, Outside Vienna, Aus...      7605
# 3           5  The Manhattan Transcripts Project, New York, N...      7056
# 4           6  Villa, project, outside Vienna, Austria, Exter...      7605
#
#                        Name  Date
# 0               Otto Wagner  1896  \
# 1  Christian de Portzamparc  1987
# 2                Emil Hoppe  1903
# 3           Bernard Tschumi  1980
# 4                Emil Hoppe  1903
#
#                                               Medium
# 0      Ink and cut-and-pasted painted pages on paper  \
# 1                  Paint and colored pencil on print
# 2  Graphite, pen, color pencil, ink, and gouache ...
# 3  Photographic reproduction with colored synthet...
# 4  Graphite, color pencil, ink, and gouache on tr...
#
#                            Dimensions Acquisition Date
# 0  19 1/8 x 66 1/2" (48.6 x 168.9 cm)       1996-04-09  \
# 1       16 x 11 3/4" (40.6 x 29.8 cm)       1995-01-17
# 2   13 1/2 x 12 1/2" (34.3 x 31.8 cm)       1997-01-15
# 3           20 x 20" (50.8 x 50.8 cm)       1995-01-17
# 4    15 1/8 x 7 1/2" (38.4 x 19.1 cm)       1997-01-15
#
#                                               Credit             Department
# 0  Fractional and promised gift of Jo Carole and ...  Architecture & Design  \
# 1  Gift of the architect in honor of Lily Auchinc...  Architecture & Design
# 2             Gift of Jo Carole and Ronald S. Lauder  Architecture & Design
# 3  Purchase and partial gift of the architect in ...  Architecture & Design
# 4             Gift of Jo Carole and Ronald S. Lauder  Architecture & Design
#
#   Classification Object Number
# 0   Architecture      885.1996
# 1   Architecture        1.1995
# 2   Architecture        1.1997
# 3   Architecture        2.1995
# 4   Architecture        2.1997

# %%
#extract date with regex, to get a clean year. first 4 digits only, create new column 'Year'

artworks['Year'] = artworks['Date'].str.extract('(\d{4})')

# %%
#check for null values
artworks.isna().sum()
# Out:
# Artwork ID              0
# Title                  62
# Artist ID            1460
# Name                 1460
# Date                 2312
# Medium              11919
# Dimensions          11463
# Acquisition Date     5463
# Credit               3070
# Department              0
# Classification          0
# Object Number           0
# Year                 3451
# dtype: int64

# %%
#check how many artists in the df
artworks['Name'].value_counts()
# Out:
# Name
# Eugène Atget                5050
# Louise Bourgeois            3318
# Ludwig Mies van der Rohe    2566
# Unknown photographer        1575
# Jean Dubuffet               1435
#                             ...
# Philip von Schantz             1
# Hubert Kiecol                  1
# Alberico Morena                1
# Jeffrey Ingram Stone           1
# Ely Ramen                      1
# Name: count, Length: 13530, dtype: int64

# %%
#check how many classifications in the df
artworks['Classification'].value_counts()
# Out:
# Classification
# Print                             30807
# Photograph                        29909
# Illustrated Book                  26160
# Drawing                           11735
# Design                            11223
# Mies van der Rohe Archive          3331
# Architecture                       2947
# Video                              2363
# Film                               2292
# Painting                           2270
# Sculpture                          1669
# Multiple                           1030
# (not assigned)                     1029
# Frank Lloyd Wright Archive          785
# Periodical                          741
# Installation                        596
# Work on Paper                       436
# Audio                               429
# Media                               343
# Ephemera                             89
# Textile                              33
# Performance                          24
# Collage                               9
# Photography Research/Reference        4
# Software                              3
# Film (object)                         3
# Furniture and Interiors               1
# Product Design                        1
# Name: count, dtype: int64

# %%
#check how many departments in the df
artworks['Department'].value_counts()
# Out:
# Department
# Prints & Illustrated Books               60128
# Photography                              29161
# Architecture & Design                    18269
# Drawings                                 11027
# Painting & Sculpture                      3806
# Film                                      3088
# Media and Performance Art                 2627
# Fluxus Collection                         2135
# Architecture & Design - Image Archive       21
# Name: count, dtype: int64

# %%
artists = pd.read_csv('../data_MoMa/artists.csv')
artists
# Out:
#        Artist ID             Name Nationality Gender  Birth Year  Death Year
# 0              1   Robert Arneson    American   Male      1930.0      1992.0
# 1              2   Doroteo Arnaiz     Spanish   Male      1936.0         NaN
# 2              3      Bill Arnold    American   Male      1941.0         NaN
# 3              4  Charles Arnoldi    American   Male      1946.0         NaN
# 4              5      Per Arnoldi      Danish   Male      1941.0         NaN
# ...          ...              ...         ...    ...         ...         ...
# 15086      67452      Liu Jianhua     Chinese   Male      1962.0         NaN
# 15087      67453         Leng Lin     Chinese   Male      1965.0         NaN
# 15088      67652     Ellie Nagler         NaN    NaN         NaN         NaN
# 15089      67694   Glenn Williams         NaN   Male         NaN         NaN
# 15090      67695        Ely Ramen         NaN    NaN         NaN         NaN
#
# [15091 rows x 6 columns]

# %%
#check for null values
artists.isna().sum()
# Out:
# Artist ID          0
# Name               0
# Nationality     2488
# Gender          3072
# Birth Year      3854
# Death Year     10512
# dtype: int64

# %%
# import dataframe into sql

# define asking for password
password = getpass("Please enter your password: ")
# Out:
# Please enter your password: ········

# %%
def load_dataframe_to_mysql(df, database, table, username, password, host='localhost', port=3306):
    """
    Load a Pandas DataFrame into a MySQL database table.
    
    Parameters:
    df (pandas.DataFrame): 
    database (str): 
    table (str): 
    username (str): 
    password (str): 
    host (str, optional): The hostname or IP address of the MySQL server (default is 'localhost').
    port (int, optional): The port number to use to connect to the MySQL server (default is 3306).
    """
    
    # create a MySQL engine using sqlalchemy
    engine = create_engine(f'mysql://{username}:{password}@{host}:{port}/{database}')

    # write the dataframe to a SQL table
    df.to_sql(name=table, con=engine, if_exists='replace', index=False)

    # close the database connection
    engine.dispose()

# %%
load_dataframe_to_mysql(artworks, 'moma', 'artworks', 'root', password)

# %%
load_dataframe_to_mysql(artists, 'moma', 'artists', 'root', password)

# %%
dbName = "moma"

# %%
connectionData=f"mysql+pymysql://root:{password}@localhost/{dbName}"

# %%
engine = alch.create_engine(connectionData)

# %%
# join artworks + artists

artworks_artists = pd.read_sql_query("""

SELECT Title, Year, Department, Classification, Medium, `Acquisition Date`, artists.*
	FROM artworks
		JOIN artists
			ON artists.`Artist ID` = artworks.`Artist ID`;

""", engine)

artworks_artists
# Out:
#                                                     Title  Year
# 0                              Earth-Cloud House, project  1970  \
# 1       Villa Snellman, Djursholm, Sweden, Elevation o...  1917
# 2       Villa Snellman, Djursholm, Sweden, Exterior el...  1917
# 3       Villa Snellman, Djursholm, Sweden, Exterior el...  1917
# 4            Villa Snellman, Djursholm, Sweden, Site plan  1917
# ...                                                   ...   ...
# 128797                                           Big Wack  1983
# 128798                                                Dig  1985
# 128799                                  Sylvester's Light  1984
# 128800                                                M&A  2013
# 128801                           Portrait of Takako Saito  None
#
#                         Department Classification
# 0            Architecture & Design   Architecture  \
# 1            Architecture & Design   Architecture
# 2            Architecture & Design   Architecture
# 3            Architecture & Design   Architecture
# 4            Architecture & Design   Architecture
# ...                            ...            ...
# 128797                        Film           Film
# 128798                        Film           Film
# 128799                        Film          Video
# 128800   Media and Performance Art    Performance
# 128801  Prints & Illustrated Books     Photograph
#
#                                                    Medium Acquisition Date
# 0                                                Graphite       1980-01-08  \
# 1       Graphite and crayon on tracing paper mounted o...       1990-01-17
# 2                                           Ink on ozalid       1990-01-17
# 3                                           Ink on ozalid       1990-01-17
# 4       Graphite and crayon on tracing paper mounted o...       1990-01-17
# ...                                                   ...              ...
# 128797                                     Super 8mm film       2016-10-18
# 128798                                     Super 8mm film       2016-10-18
# 128799                                              Video       2016-10-18
# 128800  Performance, props, and algorithmic trading st...       2016-12-15
# 128801                               Gelatin silver print       2008-10-08
#
#         Artist ID                 Name Nationality Gender  Birth Year
# 0              47      Raimund Abraham    American   Male      1933.0  \
# 1              27  Erik Gunnar Asplund     Swedish   Male      1885.0
# 2              27  Erik Gunnar Asplund     Swedish   Male      1885.0
# 3              27  Erik Gunnar Asplund     Swedish   Male      1885.0
# 4              27  Erik Gunnar Asplund     Swedish   Male      1885.0
# ...           ...                  ...         ...    ...         ...
# 128797      67349         Julius Klein    American   None      1951.0
# 128798      67349         Julius Klein    American   None      1951.0
# 128799      67349         Julius Klein    American   None      1951.0
# 128800      49568     GOLDIN + SENNEBY     Swedish   None      2004.0
# 128801      21398      George Maciunas    American   Male      1931.0
#
#         Death Year
# 0           2010.0
# 1           1940.0
# 2           1940.0
# 3           1940.0
# 4           1940.0
# ...            ...
# 128797         NaN
# 128798         NaN
# 128799         NaN
# 128800         NaN
# 128801      1978.0
#
# [128802 rows x 12 columns]

# %%
#convert Birth year and Death year to string
#artworks_artists['Birth Year'].astype(str)

artworks_artists['Birth Year'].isna().sum()
# Out:
# 8157

# %%
artworks_artists['Birth Year'].astype(str)
# Out:
# 0         1933.0
# 1         1885.0
# 2         1885.0
# 3         1885.0
# 4         1885.0
#            ...
# 128797    1951.0
# 128798    1951.0
# 128799    1951.0
# 128800    2004.0
# 128801    1931.0
# Name: Birth Year, Length: 128802, dtype: object

# %%
artworks_artists['Birth Year'] = artworks_artists['Birth Year'].apply(lambda x: str(x))

# %%
#extract date with regex, to get a clean year. first 4 digits only

artworks_artists['Birth Year'] = artworks_artists['Birth Year'].str.extract('(\d{4})')

# %%
artworks_artists['Death Year'] = artworks_artists['Death Year'].apply(lambda x: str(x))

# %%
#extract date with regex, to get a clean year. first 4 digits only

artworks_artists['Death Year'] = artworks_artists['Death Year'].str.extract('(\d{4})')

# %%
artworks_artists.Gender.unique()
# Out:
# array(['Male', None, 'Female', 'male'], dtype=object)

# %%
# edit Gender column
# new list with valid entries

F_M = ['Female', 'Male']

# %%
#rename to unknown if not Male or Female
artworks_artists.Gender = artworks_artists.Gender.apply(lambda x: 'unknown' if x not in F_M else x)

# %%
#artworks_artists.Year = artworks_artists.Year.apply(lambda x: str(x))

# %%
artworks_artists['Year'] = pd.to_datetime(artworks_artists['Year'], format)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 artworks_artists['Year'] = pd.to_datetime(artworks_artists['Year'], format)
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1046, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044             result = arg.tz_localize("utc")
#    1045 elif isinstance(arg, ABCSeries):
# -> 1046     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047     if not cache_array.empty:
#    1048         result = arg.map(cache_array)
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:250, in _maybe_cache(arg, format, cache, convert_listlike)
#     248 unique_dates = unique(arg)
#     249 if len(unique_dates) < len(arg):
# --> 250     cache_dates = convert_listlike(unique_dates, format)
#     251     # GH#45319
#     252     try:
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:453, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     451 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     452 if format is not None and format != "mixed":
# --> 453     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     455 result, tz_parsed = objects_to_datetime64ns(
#     456     arg,
#     457     dayfirst=dayfirst,
#    (...)
#     461     allow_object=True,
#     462 )
#     464 if tz_parsed is not None:
#     465     # We can take a shortcut since the datetime64 numpy array
#     466     # is in UTC
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:484, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     473 def _array_strptime_with_fallback(
#     474     arg,
#     475     name,
#    (...)
#     479     errors: str,
#     480 ) -> Index:
#     481     """
#     482     Call array_strptime, with fallback behavior depending on 'errors'.
#     483     """
# --> 484     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     485     if any(tz is not None for tz in timezones):
#     486         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/pandas/_libs/tslibs/strptime.pyx:191, in pandas._libs.tslibs.strptime.array_strptime()
#
# AssertionError:

# %%
artworks_artists['Year'] = artworks_artists['Year'].astype('datetime64[ns]')
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 artworks_artists['Year'] = artworks_artists['Year'].astype('datetime64[ns]')
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/pandas/core/generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/pandas/core/internals/managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# --> 451 return self.apply(
#     452     "astype",
#     453     dtype=dtype,
#     454     copy=copy,
#     455     errors=errors,
#     456     using_cow=using_copy_on_write(),
#     457 )
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/pandas/core/internals/managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353     result_blocks = extend_blocks(applied, result_blocks)
#     355 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/pandas/core/internals/blocks.py:511, in Block.astype(self, dtype, copy, errors, using_cow)
#     491 """
#     492 Coerce to the new dtype.
#     493
#    (...)
#     507 Block
#     508 """
#     509 values = self.values
# --> 511 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     513 new_values = maybe_coerce_values(new_values)
#     515 refs = None
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:242, in astype_array_safe(values, dtype, copy, errors)
#     239     dtype = dtype.numpy_dtype
#     241 try:
# --> 242     new_values = astype_array(values, dtype, copy=copy)
#     243 except (ValueError, TypeError):
#     244     # e.g. _astype_nansafe can fail on object-dtype of strings
#     245     #  trying to convert to float
#     246     if errors == "ignore":
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:187, in astype_array(values, dtype, copy)
#     184     values = values.astype(dtype, copy=copy)
#     186 else:
# --> 187     values = _astype_nansafe(values, dtype, copy=copy)
#     189 # in pandas we don't store numpy str dtypes, so convert to object
#     190 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:114, in _astype_nansafe(arr, dtype, copy, skipna)
#     111 if is_datetime64_dtype(dtype):
#     112     from pandas import to_datetime
# --> 114     dti = to_datetime(arr.ravel())
#     115     dta = dti._data.reshape(arr.shape)
#     116     return dta.astype(dtype, copy=False)._ndarray
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1069, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061 try:
#    1062     # error: Argument 1 to "_maybe_cache" has incompatible type
#    1063     # "Union[float, str, datetime, List[Any], Tuple[Any, ...], ExtensionArray,
#    1064     # ndarray[Any, Any], Series]"; expected "Union[List[Any], Tuple[Any, ...],
#    1065     # Union[Union[ExtensionArray, ndarray[Any, Any]], Index, Series], Series]"
#    1066     argc = cast(
#    1067         Union[list, tuple, ExtensionArray, np.ndarray, "Series", Index], arg
#    1068     )
# -> 1069     cache_array = _maybe_cache(argc, format, cache, convert_listlike)
#    1070 except OutOfBoundsDatetime:
#    1071     # caching attempts to create a DatetimeIndex, which may raise
#    1072     # an OOB. If that's the desired behavior, then just reraise...
#    1073     if errors == "raise":
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:250, in _maybe_cache(arg, format, cache, convert_listlike)
#     248 unique_dates = unique(arg)
#     249 if len(unique_dates) < len(arg):
# --> 250     cache_dates = convert_listlike(unique_dates, format)
#     251     # GH#45319
#     252     try:
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:453, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     451 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     452 if format is not None and format != "mixed":
# --> 453     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     455 result, tz_parsed = objects_to_datetime64ns(
#     456     arg,
#     457     dayfirst=dayfirst,
#    (...)
#     461     allow_object=True,
#     462 )
#     464 if tz_parsed is not None:
#     465     # We can take a shortcut since the datetime64 numpy array
#     466     # is in UTC
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:484, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     473 def _array_strptime_with_fallback(
#     474     arg,
#     475     name,
#    (...)
#     479     errors: str,
#     480 ) -> Index:
#     481     """
#     482     Call array_strptime, with fallback behavior depending on 'errors'.
#     483     """
# --> 484     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     485     if any(tz is not None for tz in timezones):
#     486         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/pandas/_libs/tslibs/strptime.pyx:530, in pandas._libs.tslibs.strptime.array_strptime()
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/pandas/_libs/tslibs/strptime.pyx:333, in pandas._libs.tslibs.strptime.array_strptime()
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/pandas/_libs/tslibs/np_datetime.pyx:218, in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 1501-01-01 00:00:00, at position 196. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
artworks_artists.Year
# Out:
# 0         1970
# 1         1917
# 2         1917
# 3         1917
# 4         1917
#           ...
# 128797    1983
# 128798    1985
# 128799    1984
# 128800    2013
# 128801    None
# Name: Year, Length: 128802, dtype: object

# %%
artworks_artists.sample()

# %%
# save clean dataset
artworks_artists.to_csv("../data_MoMa/artworks_artists.csv", index=False)

# %%
# test if the file was saved correctly, by loading it
artworks_artists = pd.read_csv("../data_MoMa/artworks_artists.csv")
artworks_artists
# Out:
#                                                     Title    Year
# 0                              Earth-Cloud House, project  1970.0  \
# 1       Villa Snellman, Djursholm, Sweden, Elevation o...  1917.0
# 2       Villa Snellman, Djursholm, Sweden, Exterior el...  1917.0
# 3       Villa Snellman, Djursholm, Sweden, Exterior el...  1917.0
# 4            Villa Snellman, Djursholm, Sweden, Site plan  1917.0
# ...                                                   ...     ...
# 128797                                           Big Wack  1983.0
# 128798                                                Dig  1985.0
# 128799                                  Sylvester's Light  1984.0
# 128800                                                M&A  2013.0
# 128801                           Portrait of Takako Saito     NaN
#
#                         Department Classification
# 0            Architecture & Design   Architecture  \
# 1            Architecture & Design   Architecture
# 2            Architecture & Design   Architecture
# 3            Architecture & Design   Architecture
# 4            Architecture & Design   Architecture
# ...                            ...            ...
# 128797                        Film           Film
# 128798                        Film           Film
# 128799                        Film          Video
# 128800   Media and Performance Art    Performance
# 128801  Prints & Illustrated Books     Photograph
#
#                                                    Medium Acquisition Date
# 0                                                Graphite       1980-01-08  \
# 1       Graphite and crayon on tracing paper mounted o...       1990-01-17
# 2                                           Ink on ozalid       1990-01-17
# 3                                           Ink on ozalid       1990-01-17
# 4       Graphite and crayon on tracing paper mounted o...       1990-01-17
# ...                                                   ...              ...
# 128797                                     Super 8mm film       2016-10-18
# 128798                                     Super 8mm film       2016-10-18
# 128799                                              Video       2016-10-18
# 128800  Performance, props, and algorithmic trading st...       2016-12-15
# 128801                               Gelatin silver print       2008-10-08
#
#         Artist ID                 Name Nationality   Gender  Birth Year
# 0              47      Raimund Abraham    American     Male      1933.0  \
# 1              27  Erik Gunnar Asplund     Swedish     Male      1885.0
# 2              27  Erik Gunnar Asplund     Swedish     Male      1885.0
# 3              27  Erik Gunnar Asplund     Swedish     Male      1885.0
# 4              27  Erik Gunnar Asplund     Swedish     Male      1885.0
# ...           ...                  ...         ...      ...         ...
# 128797      67349         Julius Klein    American  unknown      1951.0
# 128798      67349         Julius Klein    American  unknown      1951.0
# 128799      67349         Julius Klein    American  unknown      1951.0
# 128800      49568     GOLDIN + SENNEBY     Swedish  unknown      2004.0
# 128801      21398      George Maciunas    American     Male      1931.0
#
#         Death Year  decade
# 0           2010.0  1970.0
# 1           1940.0  1910.0
# 2           1940.0  1910.0
# 3           1940.0  1910.0
# 4           1940.0  1910.0
# ...            ...     ...
# 128797         NaN  1980.0
# 128798         NaN  1980.0
# 128799         NaN  1980.0
# 128800         NaN  2010.0
# 128801      1978.0     NaN
#
# [128802 rows x 13 columns]

# %%
#not sure why the saved file converts Year to float ??

# %%
def year (x):
    if type(x) == str:
        return x[:-1] + '0'

# %%
artworks_artists['decade'] = artworks_artists['Year'].apply(lambda x: year(x))

# %%
artworks_artists['decade']
# Out:
# 0         1970
# 1         1910
# 2         1910
# 3         1910
# 4         1910
#           ...
# 128797    1980
# 128798    1980
# 128799    1980
# 128800    2010
# 128801    None
# Name: decade, Length: 128802, dtype: object

# %%
artworks_artists
# Out:
#                                                     Title  Year
# 0                              Earth-Cloud House, project  1970  \
# 1       Villa Snellman, Djursholm, Sweden, Elevation o...  1917
# 2       Villa Snellman, Djursholm, Sweden, Exterior el...  1917
# 3       Villa Snellman, Djursholm, Sweden, Exterior el...  1917
# 4            Villa Snellman, Djursholm, Sweden, Site plan  1917
# ...                                                   ...   ...
# 128797                                           Big Wack  1983
# 128798                                                Dig  1985
# 128799                                  Sylvester's Light  1984
# 128800                                                M&A  2013
# 128801                           Portrait of Takako Saito  None
#
#                         Department Classification
# 0            Architecture & Design   Architecture  \
# 1            Architecture & Design   Architecture
# 2            Architecture & Design   Architecture
# 3            Architecture & Design   Architecture
# 4            Architecture & Design   Architecture
# ...                            ...            ...
# 128797                        Film           Film
# 128798                        Film           Film
# 128799                        Film          Video
# 128800   Media and Performance Art    Performance
# 128801  Prints & Illustrated Books     Photograph
#
#                                                    Medium Acquisition Date
# 0                                                Graphite       1980-01-08  \
# 1       Graphite and crayon on tracing paper mounted o...       1990-01-17
# 2                                           Ink on ozalid       1990-01-17
# 3                                           Ink on ozalid       1990-01-17
# 4       Graphite and crayon on tracing paper mounted o...       1990-01-17
# ...                                                   ...              ...
# 128797                                     Super 8mm film       2016-10-18
# 128798                                     Super 8mm film       2016-10-18
# 128799                                              Video       2016-10-18
# 128800  Performance, props, and algorithmic trading st...       2016-12-15
# 128801                               Gelatin silver print       2008-10-08
#
#         Artist ID                 Name Nationality   Gender Birth Year
# 0              47      Raimund Abraham    American     Male       1933  \
# 1              27  Erik Gunnar Asplund     Swedish     Male       1885
# 2              27  Erik Gunnar Asplund     Swedish     Male       1885
# 3              27  Erik Gunnar Asplund     Swedish     Male       1885
# 4              27  Erik Gunnar Asplund     Swedish     Male       1885
# ...           ...                  ...         ...      ...        ...
# 128797      67349         Julius Klein    American  unknown       1951
# 128798      67349         Julius Klein    American  unknown       1951
# 128799      67349         Julius Klein    American  unknown       1951
# 128800      49568     GOLDIN + SENNEBY     Swedish  unknown       2004
# 128801      21398      George Maciunas    American     Male       1931
#
#        Death Year decade
# 0            2010   1970
# 1            1940   1910
# 2            1940   1910
# 3            1940   1910
# 4            1940   1910
# ...           ...    ...
# 128797        NaN   1980
# 128798        NaN   1980
# 128799        NaN   1980
# 128800        NaN   2010
# 128801       1978   None
#
# [128802 rows x 13 columns]
